# %%
name="anusha"
age=29
gender="female"
location="guduru"
qulification="BSC COMPUTER SICENCE"
hubbies="reading"
git_repo_name="dev_ballproduct"
best_friendsnames=["anu","sri","manju","buddi","benny"]

# %%
print(name,\n,age\ngender\nqulification\nhubbies\ngit_repo_name\nbest_friendsnames)
# Out:
#   Cell In[4], line 1
#     print(name,\n,age\ngender\nqulification\nhubbies\ngit_repo_name\nbest_friendsnames)
#                 ^
# SyntaxError: unexpected character after line continuation character

# %%
name
# Out:
# 'anusha'

# %%
age
# Out:
# 29

# %%
gender
# Out:
# 'female'

# %%
location
# Out:
# 'guduru'

# %%
qulification
# Out:
# 'BSC COMPUTER SICENCE'

# %%
hubbies
# Out:
# 'reading'

# %%
git_repo_name
# Out:
# 'dev_ballproduct'

# %%
best_friendsnames
# Out:
# ['anu', 'sri', 'manju', 'buddi', 'benny']
